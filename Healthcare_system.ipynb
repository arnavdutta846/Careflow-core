# %%
mamba install pandas
# Out:
# mambajs 0.21.4
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas
# Channels: emscripten-forge-4x, conda-forge
#
# Solving environment...
# Solving took 4.960 seconds
#   Name           Version  Build                Channel
# --------------------------------------------------------------------
# + pandas         3.0.5    np23py313h1e705a5_0  emscripten-forge-4x
# + python-tzdata  2026.3   pyhd8ed1ab_0         conda-forge
# - pip            26.1.2   pyh145f28c_0         conda-forge

# %%
import pandas as pd
df =pd.read_csv("Healthcare2.csv")
df
# Out:
#       Event_ID Case_ID Patient_ID  Event_Order      Activity  \
# 0      E000001  C00001     P00001            1  Registration
# 1      E000002  C00001     P00001            2        Triage
# 2      E000003  C00001     P00001            3        Doctor
# 3      E000004  C00001     P00001            4      Pharmacy
# 4      E000005  C00001     P00001            5     Discharge
# ...        ...     ...        ...          ...           ...
# 24995  E024996  C04657     P04657            6     Discharge
# 24996  E024997  C04658     P04658            1  Registration
# 24997  E024998  C04658     P04658            2        Triage
# 24998  E024999  C04658     P04658            3        Doctor
# 24999  E025000  C04658     P04658            4     Discharge
#
#                  Department  Event_Date Event_Time         Timestamp  \
# 0                Front Desk  13-10-2026   10:35:00  13-10-2026 10:35
# 1      Emergency Department  13-10-2026   10:55:00  13-10-2026 10:55
# ...

# %%
df.head()
df.shape
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Event_ID             25000 non-null  str
#  1   Case_ID              25000 non-null  str
#  2   Patient_ID           25000 non-null  str
#  3   Event_Order          25000 non-null  int64
#  4   Activity             25000 non-null  str
#  5   Department           25000 non-null  str
#  6   Event_Date           25000 non-null  str
#  7   Event_Time           25000 non-null  str
#  8   Timestamp            25000 non-null  str
#  9   Patient_Gender       25000 non-null  str
#  10  Patient_Age          25000 non-null  int64
#  11  Patient_Race         25000 non-null  str
#  12  Department_Referral  25000 non-null  str
#  13  Admission_Flag       25000 non-null  int64
#  14  Previous_Activity    20342 non-null  str
#  15  Waiting_Time_Min     25000 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# Event_ID                   0
# Case_ID                    0
# Patient_ID                 0
# Event_Order                0
# Activity                   0
# Department                 0
# Event_Date                 0
# Event_Time                 0
# Timestamp                  0
# Patient_Gender             0
# Patient_Age                0
# Patient_Race               0
# Department_Referral        0
# Admission_Flag             0
# Previous_Activity       4658
# Waiting_Time_Min           0
# Event_Status               0
# Rework_Reason          24600
# dtype: int64

# %%
df= df.drop(columns=["Patient_Race","Rework_Reason"])
df
# Out:
#       Event_ID Case_ID Patient_ID  Event_Order      Activity  \
# 0      E000001  C00001     P00001            1  Registration
# 1      E000002  C00001     P00001            2        Triage
# 2      E000003  C00001     P00001            3        Doctor
# 3      E000004  C00001     P00001            4      Pharmacy
# 4      E000005  C00001     P00001            5     Discharge
# ...        ...     ...        ...          ...           ...
# 24995  E024996  C04657     P04657            6     Discharge
# 24996  E024997  C04658     P04658            1  Registration
# 24997  E024998  C04658     P04658            2        Triage
# 24998  E024999  C04658     P04658            3        Doctor
# 24999  E025000  C04658     P04658            4     Discharge
#
#                  Department  Event_Date Event_Time         Timestamp  \
# 0                Front Desk  13-10-2026   10:35:00  13-10-2026 10:35
# 1      Emergency Department  13-10-2026   10:55:00  13-10-2026 10:55
# ...

# %%
df.isnull().sum()
# Out:
# Event_ID                  0
# Case_ID                   0
# Patient_ID                0
# Event_Order               0
# Activity                  0
# Department                0
# Event_Date                0
# Event_Time                0
# Timestamp                 0
# Patient_Gender            0
# Patient_Age               0
# Department_Referral       0
# Admission_Flag            0
# Previous_Activity      4658
# Waiting_Time_Min          0
# Event_Status              0
# dtype: int64

# %%
df.to_csv("Healthsystem.csv",index=False)

# %%
df=pd.read_csv("Healthsystem.csv")
df
# Out:
#       Event_ID Case_ID Patient_ID  Event_Order      Activity  \
# 0      E000001  C00001     P00001            1  Registration
# 1      E000002  C00001     P00001            2        Triage
# 2      E000003  C00001     P00001            3        Doctor
# 3      E000004  C00001     P00001            4      Pharmacy
# 4      E000005  C00001     P00001            5     Discharge
# ...        ...     ...        ...          ...           ...
# 24995  E024996  C04657     P04657            6     Discharge
# 24996  E024997  C04658     P04658            1  Registration
# 24997  E024998  C04658     P04658            2        Triage
# 24998  E024999  C04658     P04658            3        Doctor
# 24999  E025000  C04658     P04658            4     Discharge
#
#                  Department  Event_Date Event_Time         Timestamp  \
# 0                Front Desk  13-10-2026   10:35:00  13-10-2026 10:35
# 1      Emergency Department  13-10-2026   10:55:00  13-10-2026 10:55
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Event_ID"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.sort_values(
    by=["Case_ID", "Event_Order"])

# %%
df.groupby("Case_ID")["Activity"].apply(
    list
)
# Out:
# Case_ID
# C00001    [Registration, Triage, Doctor, Pharmacy, Disch...
# C00002    [Registration, Triage, Doctor, Pharmacy, Disch...
# C00003    [Registration, Triage, Doctor, Pharmacy, Disch...
# C00004    [Registration, Triage, Doctor, Pharmacy, Disch...
# C00005    [Registration, Triage, Doctor, Pharmacy, Disch...
#                                 ...
# C04654    [Registration, Triage, Doctor, Pharmacy, Disch...
# C04655    [Registration, Triage, Doctor, Pharmacy, Disch...
# C04656    [Registration, Triage, Doctor, Imaging, Triage...
# C04657    [Registration, Triage, Doctor, Lab, Doctor, Di...
# C04658            [Registration, Triage, Doctor, Discharge]
# Name: Activity, Length: 4658, dtype: object

# %%
df[df["Waiting_Time_Min"] < 0]
# Out:
# Empty DataFrame
# Columns: [Event_ID, Case_ID, Patient_ID, Event_Order, Activity, Department, Event_Date, Event_Time, Timestamp, Patient_Gender, Patient_Age, Department_Referral, Admission_Flag, Previous_Activity, Waiting_Time_Min, Event_Status]
# Index: []

# %%
df = df.sort_values(
    by=["Case_ID", "Event_Order"]
)

# %%
df["Timestamp"] = pd.to_datetime(df["Timestamp"])
# Out:
# /tmp/xpython_42/3991263233.py:1: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df["Timestamp"] = pd.to_datetime(df["Timestamp"])

# %%
df["Timestamp"] = pd.to_datetime(df["Timestamp"])

# %%
df = df.sort_values(
    by=["Case_ID", "Timestamp"]
)

# %%
df = df.sort_values(
    by=["Case_ID", "Timestamp"]
)

# %%
df["Waiting_Time_Min"].mean()
# Out:
# np.float64(27.16244)

# %%
df.groupby("Activity")[
    "Waiting_Time_Min"
].mean().sort_values(ascending=False)
# Out:
# Activity
# Imaging         73.299000
# Lab             65.815000
# Doctor          44.791052
# Triage          27.268683
# Pharmacy        25.280540
# Discharge       19.715328
# Registration     0.000000
# Name: Waiting_Time_Min, dtype: float64

# %%
df.groupby("Department")[
    "Waiting_Time_Min"
].mean()
# Out:
# Department
# Emergency Department    31.692935
# Front Desk               0.000000
# Laboratory              65.815000
# Pharmacy                25.280540
# Radiology               73.299000
# Name: Waiting_Time_Min, dtype: float64

# %%
case_wait = df.groupby("Case_ID")[
    "Waiting_Time_Min"
].sum()

# %%
activity_counts = df.groupby(
    ["Case_ID", "Activity"]
).size()

# %%
df.groupby(
    ["Department", "Department_Referral"]
).size()
# Out:
# Department            Department_Referral
# Emergency Department  Ambulance              3231
#                       General                3175
#                       Primary Care           3113
#                       Self                   3026
#                       Specialist             3139
# Front Desk            Ambulance               968
#                       General                 942
#                       Primary Care            923
#                       Self                    894
#                       Specialist              931
# Laboratory            Ambulance                85
#                       General                  80
#                       Primary Care             74
#                       Self                     77
#                       Specialist               84
# Pharmacy              Ambulance               698
#                       General                 646
#                       Primary Care            646
# ...

# %%
df.groupby("Admission_Flag")[
    "Waiting_Time_Min"
].mean()
# Out:
# Admission_Flag
# 0    27.151183
# 1    27.213061
# Name: Waiting_Time_Min, dtype: float64

# %%
process_df = df[
    ["Case_ID", "Activity", "Timestamp"]
].copy()

# %%
df= pd.read_csv("Healthcare2.csv")
df
# Out:
#       Event_ID Case_ID Patient_ID  Event_Order      Activity  \
# 0      E000001  C00001     P00001            1  Registration
# 1      E000002  C00001     P00001            2        Triage
# 2      E000003  C00001     P00001            3        Doctor
# 3      E000004  C00001     P00001            4      Pharmacy
# 4      E000005  C00001     P00001            5     Discharge
# ...        ...     ...        ...          ...           ...
# 24995  E024996  C04657     P04657            6     Discharge
# 24996  E024997  C04658     P04658            1  Registration
# 24997  E024998  C04658     P04658            2        Triage
# 24998  E024999  C04658     P04658            3        Doctor
# 24999  E025000  C04658     P04658            4     Discharge
#
#                  Department  Event_Date Event_Time         Timestamp  \
# 0                Front Desk  13-10-2026   10:35:00  13-10-2026 10:35
# 1      Emergency Department  13-10-2026   10:55:00  13-10-2026 10:55
# ...

# %%
df.to_csv("Healthcare2.csv",index=False)
